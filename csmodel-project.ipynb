# %% [markdown]
# # I. **About the Dataset**
#
# ---

# %% [markdown]
# ## **Brief Description**
#
# The `Indicators of Heart Disease (2022)` dataset provides essential information about recognized indicators of heart disease. Some of the key indicators in the dataset include obesity (indicated by a high BMI), not getting enough sleep, diabetic, etc.. Identifying the patterns of a higher-than-normal likelihood of getting a heart disease is necessary for people to take the necessary precautionary measures.

# %% [markdown]
# ## **Description of the Data Collection Process**
#
# - The dataset is obtained from the Centers for Disease Control and Prevention (CDC) to collect data on the health status of US residents through a cross-sectional major annual telephone survey conducted by the Behavioral Risk Factor Surveillance System (BRFSS). The survey is conducted using Random Digit Dialing (RDD), which involves contacting individuals through landline phones and mobile phones.
#
# - The BRFSS survey comprises three sections: the core modules, optional modules, and state-added modules. The core section is standardized across all states and includes questions mandated by the CDC. Optional modules are chosen by individual states. The states have the flexibility to create their own unique modules referred to as state-added questions. [Source](https://www.hhs.nd.gov/public-health/behavioral-health/north-dakota-behavioral-risk-factor-surveillance-system/brfss)
#
# - BRFSS employs iterative proportional fitting or “raking” as a data weighting technique. Raking incorporates data from cellular telephone surveys and the inclusion of additional demographic variables such as educational level, marital status, and housing status. These additional characteristics significantly improve the accuracy and comprehensiveness of the BRFSS sample, ensuring it better reflects the diverse socio-demographic composition of individual states. [Source](https://www.cdc.gov/brfss/annual_data/2022/pdf/Overview_2022-508.pdf)
#
# - The use of RDD to contact individuals through landlines and mobile phones may introduce sampling bias. Not everyone has access to phones, thus excluding certain demographic groups such as those without phone access or those who do not answer their phones. This affects the representativeness of the sample which may possibly lead to skewed conclusions. Additionally, the survey introduces response bias as respondents may not always answer the questions truthfully, which may lead to incorrect conclusions regarding health conditions.
# - Since the survey conducted is a cross-sectional survey, the dataset may not capture the changes in health conditions over time. The conclusions and insights that will be generated are limited to the year it was conducted.

# %% [markdown]
# ## **Structure Description**
#
# - Each row represents an observation from a participant in the survey performed by the CDC, with each column representing an aspect of their health and lifestyle that was asked during the survey, such as their weight, their number of sleep hours, and if they have asthma.
# - There are **246,022** observations in the dataset.
# - There are **40 variables** in the dataset.
# - The dataset does not have separate, different files that need to be combined

# %% [markdown]
# ## **Variable Discussion**
#
# 1. **State**: The state where the participant of the dataset lives.
# 2. **Sex**: The biological sex of the participant.
# 3. **GeneralHealth**: Self-reported overall health status of the participant.
# 4. **PhysicalHealthDays**: The number of days in the past month that the participant experienced physical health issues or discomfort.
# 5. **MentalHealthDays**: The number of days in the past month that the participant experienced mental health issues or emotional distress.
# 6. **LastCheckupTime**: The time since the participant's last medical checkup or examination.
# 7. **PhysicalActivities**: Whether or not the participant does physical activities.
# 8. **SleepHours**: The number of hours of sleep a participant gets on average per day.
# 9. **RemovedTeeth**: The count of the participant's teeth that have been removed or are missing.
# 10. **HadHeartAttack** (HadHeartDisease): As per the dataset expert's recommendation, this variable is about whether or not the participant has had a heart disease in the past, not necessarily just a heart attack.
# 11. **HadAngina**: Whether or not the participant has had an episode of Angina (chest pain or discomfort) in the past.
# 12. **HadStroke**: Whether or not the participant has had a stroke in the past.
# 13. **HadAsthma**: Whether or not the participant has been diagnosed with asthma.
# 14. **HadSkinCancer**: Whether or not the participant has had a diagnosis of skin cancer.
# 15. **HadCOPD**: Whether or not the participant has Chronic Obstructive Pulmonary Disease (COPD).
# 16. **HadDepressiveDisorder**: Whether or not the participant has been diagnosed with a depressive disorder.
# 17. **HadKidneyDisease**: Whether or not the participant has been diagnosed with kidney disease.
# 18. **HadArthritis**: Whether or not the participant has been diagnosed with arthritis.
# 19. **HadDiabetes**: Whether or not the participant has been diagnosed with diabetes.
# 20. **DeafOrHardOfHearing**: Whether or not the participant is deaf or hard of hearing.
# 21. **BlindOrVisionDifficulty**: Whether or not the participant is blind or has difficulty with vision.
# 22. **DifficultyConcentrating**: Whether or not the participant has difficulty concentrating or staying focused.
# 23. **DifficultyWalking**: Whether or not the participant has difficulty walking or mobility.
# 24. **DifficultyDressingBathing**: Whether or not the participant has difficulty dressing or bathing.
# 25. **DifficultyErrands**: Whether or not the participant has difficulty running daily errands or tasks.
# 26. **SmokerStatus**: The participant's current smoking status (never smoked, former smoker, current smoker).
# 27. **ECigaretteUsage**: The frequency and extent of e-cigarette usage.
# 28. **ChestScan**: Whether or not the participant has had a chest scan or imaging for a specific medical purpose.
# 29. **RaceEthnicityCategory**: The racial and ethnic background or category of the participant, and whether or not they are of Hispanic ethnicity.
# 30. **AgeCategory**: The age group to which the participant belongs.
# 31. **HeightInMeters**: The height of the participant in meters.
# 32. **WeightInKilograms**: The weight of the participant in kilograms.
# 33. **BMI**: The Body Mass Index (BMI) of the participant, calculated based on height and weight.
# 34. **AlcoholDrinkers**: Whether or not the participant consumes alcoholic beverages.
# 35. **HIVTesting**: Whether or not the participant has undergone HIV testing.
# 36. **FluVaxLast12**: Whether the participant received a flu vaccine within the last 12 months.
# 37. **PneumoVaxEver**: Whether the participant has ever received a pneumococcal vaccine.
# 38. **TetanusLast10Tdap**: Whether or not the participant has received a tetanus vaccine or Tdap (tetanus, diphtheria, and pertussis) combination vaccine.
# 39. **HighRiskLastYear**: Whether the participant was classified as "high risk" for certain health conditions within the last year.
# 40. **CovidPos**: Whether or not the participant has ever tested positive for COVID-19.
#
# Of the **40 variables** included in the dataset, the group has decided to focus on the following **8 variables** to be utilized in the study:
#
# 1. GeneralHealth
# 2. AgeCategory
# 3. HadHeartAttack
# 4. BMI
# 5. AlcoholDrinkers
# 6. SmokerStatus
# 7. SleepHours
# 8. PhysicalActivities

# %% [markdown]
# # II. **Loading the Dataset and Importing Libraries**
#
# ---

# %% [markdown]
# ### Before running the remaining code, install the following libraries
#
# ```
# pip install pandas
# pip install numpy
# pip install matplotlib
# pip install seaborn
# pip install scipy
# pip install jinja2
# ```

# %% [markdown]
# ### Import Libraries and extract csv file

# %%
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
from scipy.stats import chi2_contingency
from matplotlib.patches import Patch
from mlxtend.frequent_patterns import apriori, association_rules
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('heart_2022_no_nans.csv')

# %% [markdown]
# ### General Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246022 entries, 0 to 246021
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      246022 non-null  object
#  1   Sex                        246022 non-null  object
#  2   GeneralHealth              246022 non-null  object
#  3   PhysicalHealthDays         246022 non-null  float64
#  4   MentalHealthDays           246022 non-null  float64
#  5   LastCheckupTime            246022 non-null  object
#  6   PhysicalActivities         246022 non-null  object
#  7   SleepHours                 246022 non-null  float64
#  8   RemovedTeeth               246022 non-null  object
#  9   HadHeartAttack             246022 non-null  object
#  10  HadAngina                  246022 non-null  object
#  11  HadStroke                  246022 non-null  object
#  12  HadAsthma                  246022 non-null  object
# ...

# %%
df
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2              Alabama    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %% [markdown]
# ### Check the content of the dataset

# %%
def describe_df(df):
    for col in df.columns:
        col_dtype = df[col].dtype

        print("--------------------------------------------------------------", end="")
        print(f"\nColumn: {col} ({col_dtype})")
        # print(f"\nColumn Info: {df[col].info()}")
        print(f"\nColumn Value Counts: \n{df[col].value_counts()}")
        print("--------------------------------------------------------------\n\n")

# %%
describe_df(df)
# Out:
# --------------------------------------------------------------
# Column: State (object)
#
# Column Value Counts:
# State
# Washington              15000
# Maryland                 9165
# Minnesota                9161
# Ohio                     8995
# New York                 8923
# Texas                    7408
# Florida                  7315
# Kansas                   6145
# Wisconsin                6126
# Maine                    6013
# Iowa                     5672
# Hawaii                   5596
# Virginia                 5565
# Indiana                  5502
# South Carolina           5471
# Massachusetts            5465
# Arizona                  5462
# Utah                     5373
# Michigan                 5370
# Colorado                 5159
# Nebraska                 5107
# California               5096
# Connecticut              5053
# Georgia                  4978
# Vermont                  4845
# South Dakota             4405
# Montana                  4264
# ...

# %% [markdown]
# # III. **Data Cleaning**
#
# ---
#
# The group's chosen dataset did not require any extensive data cleaning.

# %% [markdown]
# The dataset did not have multiple representations of the same categorical value (e.g. "No" being represented as "N", "no", "n", etc.). The formatting of the values were also very consistent.

# %%
for column in ['GeneralHealth', 'AgeCategory', 'HadHeartAttack', 'AlcoholDrinkers', 'SmokerStatus', 'PhysicalActivities']:
    print(f"Unique values for {column}: {df[column].unique()}")
# Out:
# Unique values for GeneralHealth: ['Very good' 'Fair' 'Good' 'Excellent' 'Poor']
# Unique values for AgeCategory: ['Age 65 to 69' 'Age 70 to 74' 'Age 75 to 79' 'Age 80 or older'
#  'Age 50 to 54' 'Age 40 to 44' 'Age 60 to 64' 'Age 55 to 59'
#  'Age 45 to 49' 'Age 35 to 39' 'Age 25 to 29' 'Age 30 to 34'
#  'Age 18 to 24']
# Unique values for HadHeartAttack: ['No' 'Yes']
# Unique values for AlcoholDrinkers: ['No' 'Yes']
# Unique values for SmokerStatus: ['Former smoker' 'Never smoked' 'Current smoker - now smokes every day'
#  'Current smoker - now smokes some days']
# Unique values for PhysicalActivities: ['Yes' 'No']

# %% [markdown]
# Some of the variables, particularly those of numerical nature, had the wrong data type. These are:
#
# 1. AgeCategory
# 2. SleepHours
#
# They were then changed to better fit their real-life representation (i.e. numerical data --> integer/float).

# %%
df[['GeneralHealth', 'AgeCategory', 'HadHeartAttack', 'BMI', 'AlcoholDrinkers',
    'SmokerStatus', 'SleepHours', 'PhysicalActivities']].dtypes
# Out:
# GeneralHealth          object
# AgeCategory            object
# HadHeartAttack         object
# BMI                   float64
# AlcoholDrinkers        object
# SmokerStatus           object
# SleepHours            float64
# PhysicalActivities     object
# dtype: object

# %%
# Changing of datatypes
df['SleepHours'] = df['SleepHours'].astype(int)

# %% [markdown]
# There were no default values (a.k.a NaNs) in the dataset nor was there any missing data that required the use of "NaN".

# %%
df[['GeneralHealth', 'AgeCategory', 'HadHeartAttack', 'BMI', 'AlcoholDrinkers',
    'SmokerStatus', 'SleepHours', 'PhysicalActivities']].isna().sum()
# Out:
# GeneralHealth         0
# AgeCategory           0
# HadHeartAttack        0
# BMI                   0
# AlcoholDrinkers       0
# SmokerStatus          0
# SleepHours            0
# PhysicalActivities    0
# dtype: int64

# %% [markdown]
# There were duplicate data, but given that this is a large-scale survey the group decided to keep the duplicate observations as the similarities could be mere coincidences.

# %%
df[df.duplicated(subset=['GeneralHealth', 'AgeCategory', 'HadHeartAttack', 'BMI',
                 'AlcoholDrinkers', 'SmokerStatus', 'SleepHours', 'PhysicalActivities'])]
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 836            Alabama  Female     Very good                 0.0
# 867            Alabama  Female          Fair                20.0
# 1243           Alabama  Female          Good                 7.0
# 1447           Alabama    Male          Good                 1.0
# 1996            Alaska    Male     Very good                 6.0
# ...                ...     ...           ...                 ...
# 246007  Virgin Islands  Female     Very good                 0.0
# 246010  Virgin Islands    Male     Very good                 0.0
# 246015  Virgin Islands  Female     Very good                 0.0
# 246017  Virgin Islands    Male     Very good                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 836                 10.0  Within past year (anytime less than 12 months ...
# ...

# %% [markdown]
# # IV. **Data Preprocessing**
#
# ---
#
# For some of the variables, pre-processing was implemented in order to make the representation of the values easier to read and analyze.

# %% [markdown]
# `HadHeartAttack` variable will be changed to `HadHeartDisease` to be easily understood.

# %%
# Change HadHeartAttack to HadHeartDisease
df.rename(columns={'HadHeartAttack': 'HadHeartDisease'}, inplace=True)

# %% [markdown]
# A separate dataframe is made which only includes the 8 aforementioned variables that will be utilized in the study.

# %%
heart_df = df[["GeneralHealth", "AgeCategory", "HadHeartDisease", "BMI",
               "AlcoholDrinkers", "SmokerStatus", "SleepHours", "PhysicalActivities"]]
heart_df
# Out:
#        GeneralHealth      AgeCategory HadHeartDisease    BMI AlcoholDrinkers  \
# 0          Very good     Age 65 to 69              No  27.99              No
# 1          Very good     Age 70 to 74              No  30.13              No
# 2          Very good     Age 75 to 79              No  31.66             Yes
# 3               Fair  Age 80 or older              No  31.32              No
# 4               Good  Age 80 or older              No  33.07              No
# ...              ...              ...             ...    ...             ...
# 246017     Very good     Age 60 to 64              No  32.28             Yes
# 246018          Fair     Age 25 to 29              No  24.34              No
# 246019          Good     Age 65 to 69              No  29.86             Yes
# 246020     Excellent     Age 50 to 54              No  28.66              No
# 246021     Very good     Age 70 to 74             Yes  32.55              No
#
# ...

# %% [markdown]
# For the `BMI` variable, binning was used to separate certain numerical values into BMI-specific labels.
#
# Since there was too much variance between the BMI values of each observation in the dataset, it was decided that their BMI data would be binned into their own respective categories. This was done to allow for easier manipulation and observing of the BMI values in the data set.

# %%
heart_df['BMI'] = pd.cut(heart_df.BMI, bins=[0, 18.4, 24.9, 29.9, 34.9, 39.9, 49.9, 100],
                         labels=['Underweight', 'Normal', 'Overweight', 'Obese', 'Severely Obese', 'Morbidly Obese', 'Super Obese'])
heart_df
# Out:
#        GeneralHealth      AgeCategory HadHeartDisease         BMI  \
# 0          Very good     Age 65 to 69              No  Overweight
# 1          Very good     Age 70 to 74              No       Obese
# 2          Very good     Age 75 to 79              No       Obese
# 3               Fair  Age 80 or older              No       Obese
# 4               Good  Age 80 or older              No       Obese
# ...              ...              ...             ...         ...
# 246017     Very good     Age 60 to 64              No       Obese
# 246018          Fair     Age 25 to 29              No      Normal
# 246019          Good     Age 65 to 69              No  Overweight
# 246020     Excellent     Age 50 to 54              No  Overweight
# 246021     Very good     Age 70 to 74             Yes       Obese
#
#        AlcoholDrinkers   SmokerStatus  SleepHours PhysicalActivities
# 0                   No  Former smoker           9                Yes
# ...

# %% [markdown]
# For the `AgeCategory` variable, the age groups were converted to age estimates in order to allow the datatype conversion from category to integer.
#
# This sort of binning was done to allow for easier data manipulation when it comes to the age data of the different observations of the dataframe, since more functions can generally be done with integers than categories/strings.

# %%
heart_df['AgeCategory'] = heart_df['AgeCategory'].str[4:6]
heart_df.rename(columns={'AgeCategory': 'Age'}, inplace=True)

# %% [markdown]
# The data type of the `AgeCategory` will be changed to integer.

# %%
heart_df['Age'] = heart_df['Age'].astype(int)
heart_df
# Out:
#        GeneralHealth  Age HadHeartDisease         BMI AlcoholDrinkers  \
# 0          Very good   65              No  Overweight              No
# 1          Very good   70              No       Obese              No
# 2          Very good   75              No       Obese             Yes
# 3               Fair   80              No       Obese              No
# 4               Good   80              No       Obese              No
# ...              ...  ...             ...         ...             ...
# 246017     Very good   60              No       Obese             Yes
# 246018          Fair   25              No      Normal              No
# 246019          Good   65              No  Overweight             Yes
# 246020     Excellent   50              No  Overweight              No
# 246021     Very good   70             Yes       Obese              No
#
#          SmokerStatus  SleepHours PhysicalActivities
# 0       Former smoker           9                Yes
# ...

# %%
heart_df.BMI.value_counts().to_frame().style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_801a7_row0_col0 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_801a7_row1_col0 {
#   background-color: #00c89b;
#   color: #000000;
# }
# #T_801a7_row2_col0 {
#   background-color: #008eb8;
#   color: #f1f1f1;
# }
# #T_801a7_row3_col0 {
#   background-color: #0039e2;
#   color: #f1f1f1;
# }
# #T_801a7_row4_col0 {
#   background-color: #001ef0;
#   color: #f1f1f1;
# }
# #T_801a7_row5_col0 {
#   background-color: #0003fe;
#   color: #f1f1f1;
# }
# #T_801a7_row6_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_801a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_801a7_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >BMI</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# Check again the content of the current dataframe

# %%
describe_df(heart_df)
# Out:
# --------------------------------------------------------------
# Column: GeneralHealth (object)
#
# Column Value Counts:
# GeneralHealth
# Very good    86999
# Good         77409
# Excellent    41525
# Fair         30659
# Poor          9430
# Name: count, dtype: int64
# --------------------------------------------------------------
#
#
# --------------------------------------------------------------
# Column: Age (int32)
#
# Column Value Counts:
# Age
# 65    28557
# 60    26720
# 70    25739
# 55    22224
# 50    19913
# 75    18136
# 80    17816
# 40    16973
# 45    16753
# 35    15614
# 30    13346
# 18    13122
# 25    11109
# Name: count, dtype: int64
# --------------------------------------------------------------
#
#
# --------------------------------------------------------------
# Column: HadHeartDisease (object)
#
# Column Value Counts:
# HadHeartDisease
# No     232587
# Yes     13435
# Name: count, dtype: int64
# ...

# %% [markdown]
# # V. **Exploratory Data Analysis**
#
# ---
#
# The primary aim of this data analysis is to delve into and thoroughly examine lifestyle-related variables in the dataset, with the goal of gaining insight into how those variables could play a role in contracting heart diseases.

# %% [markdown]
# ## 1. What is the percentage/proportion of the dataset with and without heart disease?

# %% [markdown]
# ### Variable/s involved:
#
# - HadHeartDisease

# %%
had_heart_disease_df = heart_df['HadHeartDisease']

# multiply by 100 to get the percentage after normalizing
value_counts = had_heart_disease_df.value_counts(normalize=True) * 100
percentage_arr = value_counts.values

# %%
labels = 'Without Heart Disease', 'With Heart Disease'
sizes = percentage_arr
explode = (0, 0.3)

fig, ax = plt.subplots(figsize=(15, 9))
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors=[
       'lightskyblue', 'lightgreen'], shadow=True, startangle=180, explode=explode)

plt.show()

# %% [markdown]
# ### Interpretation
#
# Based on the data, only 5.5% of the entire dataset comprises of the participants with heart diseases and the remaining 94.5% are participants without the heart disease.

# %% [markdown]
# ## 2. Is there an association between age group and whether or not they have had heart disease?

# %% [markdown]
# ### Variables Involved
#
# - Age
# - AlcoholDrinkers

# %% [markdown]
# ### Numerical

# %%
heart_df_copy = heart_df.copy()
heart_df_copy['HadHeartDisease'] = heart_df_copy['HadHeartDisease'].map({
                                                                        'Yes': 1, 'No': 0})

percentage_heart_disease_by_age = (
    heart_df_copy.groupby('Age')['HadHeartDisease'].mean() * 100
)

print(percentage_heart_disease_by_age)
# Out:
# Age
# 18     0.381039
# 25     0.423080
# 30     0.674359
# 35     0.999103
# 40     1.343310
# 45     2.507014
# 50     3.530357
# 55     5.003600
# 60     5.894461
# 65     7.546311
# 70     9.355453
# 75    11.386193
# 80    13.616974
# Name: HadHeartDisease, dtype: float64

# %% [markdown]
# ### Visualization

# %%
# Get the dataframe with age and hadheartdisease
age_heart_df = heart_df[['Age', 'HadHeartDisease']]

# Get the values of the age column
unsorted_age_values = heart_df['Age'].unique()

# change the categorical type to int
age_values = []
for i in range(len(unsorted_age_values)):
    age_values.append(int(unsorted_age_values[i]))

# sort the values
age_values.sort()

# Create arrays for each of the age values
temp_arr = []

# separate the dataframes for each of the smoker status using query
for age_value in age_values:
    # convert int to str to be used with .query()
    age_str = str(age_value)
    # perform query
    temp_df = age_heart_df.query('Age == ' + age_str)
    # store the df to the array
    temp_arr.append(temp_df)

# Data
groups = ['18', '25', '30', '35', '40', '45',
          '50', '55', '60', '65', '70', '80 above']
with_heart_disease_values = []
without_heart_disease_values = []

# get the percentages of the smoker classifications in each age category
for i in range(len(groups)):
    without_heart_disease_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[0])
    with_heart_disease_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[1])

# %%
# Use Stacked bar chart - https://python-charts.com/part-whole/stacked-bar-chart-matplotlib/
fig, ax = plt.subplots(figsize=(15, 6))

# configure the bars/handles to represent data
ax.bar(groups, with_heart_disease_values, edgecolor="black",
       linewidth=2, color="lightseagreen", label="With Heart Disease")

# get the handles and labels using get_legend_handles_labels()
handles, labels = ax.get_legend_handles_labels()
# reverse the order of the labels and handles
ax.legend(handles[::-1], labels[::-1], loc='upper right')

# Set the axis labels
ax.set_ylabel("Percentage of Participants with Heart Disease")
ax.set_xlabel("Age Marker")

ax.set_ylim(0, 100)

# Label the specific bars with the corresponding data (percentage in this case)
for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() / 2 + bar.get_y(),
            round(bar.get_height()), ha='center',
            color='white', weight='bold', size=10)

# show the plot
plt.show()

# %% [markdown]
# ### Interpretation
#
# According to the chart above, we can see that there is a positive correlation between age and likelihood of getting a heart disease, wherein the older you get, the more likely you are to suffer from a heart-related disease.

# %% [markdown]
# ## 3. What percentage of individuals in the different age groups consume alcohol, regardless of the amount?
#
# ### Variables Involved
#
# - AlcoholDrinkers
# - HadHeartDisease

# %% [markdown]
# ### Numerical

# %% [markdown]
# Group data based on age category and compute for the proportion of alcohol drinkers for each category.

# %%
age_groups_drinker = heart_df.copy()

age_groups_drinker = age_groups_drinker.groupby('Age')['AlcoholDrinkers'].apply(
    lambda x: (x == 'Yes').mean() * 100)


print('Percentage of Drinkers From Each Age Group')
print(age_groups_drinker)
# Out:
# Percentage of Drinkers From Each Age Group
# Age
# 18    55.890870
# 25    67.665857
# 30    64.633598
# 35    62.898681
# 40    61.426972
# 45    59.637080
# 50    58.494451
# 55    55.989021
# 60    54.487275
# 65    51.948734
# 70    49.294844
# 75    46.222982
# 80    39.492591
# Name: AlcoholDrinkers, dtype: float64

# %% [markdown]
# ### Visualization

# %%
age_groups_drinker.plot(kind='bar', color="lightseagreen",
                        edgecolor="black", linewidth=2, figsize=(15, 9))

plt.title('Percentage of Individuals Consuming Alcohol by Age Marker')
plt.xlabel('Age Marker')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# ### Interpretation
#
# According to the chart above, we can see that alcohol intake is positively-skewed and generally has a negative correlation with age (except for the first few years before 30 years of age). The general trend is that the participants are less likely to be alcohol consumers the older they are.

# %% [markdown]
# ## 4. What percentage of individuals in different age groups engage in smoking, regardless of the quantity?

# %% [markdown]
# ### Variables Involved
#
# - Age
# - SmokerStatus
#
# Write the code to select SmokerStatus and Age as a dataframe.

# %%
# Get the dataframe with age and smokerstatus
age_smoker_df = heart_df[['Age', 'SmokerStatus']]

# Get the values of the age column
unsorted_age_values = heart_df['Age'].unique()

# change the categorical type to int
age_values = []
for i in range(len(unsorted_age_values)):
    age_values.append(int(unsorted_age_values[i]))

# sort the values
age_values.sort()

# Create arrays for each of the age values
temp_arr = []

# separate the dataframes for each of the smoker status using query
for age_value in age_values:
    # convert int to str to be used with .query()
    age_str = str(age_value)
    # perform query
    temp_df = age_smoker_df.query('Age == ' + age_str)
    # store the df to the array
    temp_arr.append(temp_df)

# Data
groups = ['18', '25', '30', '35', '40', '45',
          '50', '55', '60', '65', '70', '80 above']
never_smoked_values = []
former_smoker_values = []
smokes_some_days_values = []
smokes_everyday_values = []

# get the percentages of the smoker classifications in each age category
for i in range(len(groups)):
    never_smoked_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[0])
    former_smoker_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[1])
    smokes_some_days_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[2])
    smokes_everyday_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[3])

# %% [markdown]
# ## Visualization

# %%
# Use Stacked bar chart - https://python-charts.com/part-whole/stacked-bar-chart-matplotlib/
fig, ax = plt.subplots(figsize=(15, 9))

# configure the bars/handles to represent data
ax.bar(groups, never_smoked_values, edgecolor="black",
       linewidth=2, color="lightseagreen", label="Never Smoked")
ax.bar(groups, former_smoker_values, bottom=never_smoked_values,
       edgecolor="black", linewidth=2, color="yellowgreen", label="Former Smoker")
ax.bar(groups, smokes_some_days_values, bottom=np.add(
    never_smoked_values, former_smoker_values), edgecolor="black", linewidth=2, color="burlywood", label="Seldomly Smokes")
ax.bar(groups, smokes_everyday_values, bottom=np.add(never_smoked_values,
       np.add(former_smoker_values, smokes_some_days_values)), edgecolor="black", linewidth=2, color="tomato", label="Smokes Everyday")

# get the handles and labels using get_legend_handles_labels()
handles, labels = ax.get_legend_handles_labels()
# reverse the order of the labels and handles
ax.legend(handles[::-1], labels[::-1], loc='lower right')

# Set the axis labels
ax.set_ylabel("Percentage of Smokers/Non-Smokers")
ax.set_xlabel("Age Marker")

# Label the specific bars with the corresponding data (percentage in this case)
for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() / 2 + bar.get_y(),
            round(bar.get_height()), ha='center',
            color='white', weight='bold', size=10)

# rotate the x-axis labels for readability
# labels = ax.get_xticklabels()
# for label in labels:
#     label.set_rotation(90)

# show the plot
plt.show()

# %% [markdown]
# ### Interpretation
#
# According to the stacked bar chart above, we can see that the general trend among participants is that they are more likely to be active smokers if they are in the "middle" of their lifespan, and that the number of former smokers per age marker generally increases. We can also see that in general, there is a sharp decrease in overall smokers among the younger generations/age markers.

# %% [markdown]
# # 5. Are there differences in the prevalence of heart diseases between alcohol drinkers and non-alcohol drinkers in the dataset?
#
# ### Variable/s involved:
#
# - HadHeartDisease
# - AlcoholDrinkers

# %% [markdown]
# ### Numerical
#
# The main numerical summary will be the distribution of those with heart diseases among alcohol drinkers and non-alcohol drinkers.
# In order to determine whether or not the test is statistically-significant, we must get the p-value.

# %%
contingency_table = pd.crosstab(
    heart_df['AlcoholDrinkers'], heart_df['HadHeartDisease'])
chi2, p, _, _ = chi2_contingency(contingency_table)
print("P-value:", p)
# Out:
# P-value: 3.175611575035547e-296

# %% [markdown]
# ### Visualization

# %%
# Get the dataframe with AlcoholDrinkers and HadHeartDisease
alcohol_heart_df = heart_df[['AlcoholDrinkers', 'HadHeartDisease']]

# Create arrays for each of the age values
temp_arr = []

# separate the dataframes for participants who are alcoholic or non-alcoholic using query
temp_arr.append(alcohol_heart_df.query('AlcoholDrinkers == "Yes"'))
temp_arr.append(alcohol_heart_df.query('AlcoholDrinkers == "No"'))

# Data
groups = ['Non-Alcohol Drinkers', 'Alcohol Drinkers']
with_heart_disease_values = []
without_heart_disease_values = []


# get the percentages of the smoker classifications in each age category
for i in range(len(groups)):
    without_heart_disease_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[0])
    with_heart_disease_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[1])

# %%
# Use Stacked bar chart - https://python-charts.com/part-whole/stacked-bar-chart-matplotlib/
fig, ax = plt.subplots(figsize=(15, 9))

# configure the bars/handles to represent data
ax.bar(groups, with_heart_disease_values, edgecolor="black",
       linewidth=2, color="lightseagreen", label="With Heart Disease")

# get the handles and labels using get_legend_handles_labels()
handles, labels = ax.get_legend_handles_labels()
# reverse the order of the labels and handles
ax.legend(handles[::-1], labels[::-1], loc='upper right')

ax.set_ylim(0, 100)

# Set the axis labels
ax.set_ylabel("Percentage of Heart Disease Status")
ax.set_xlabel("Alcohol Drinking Status")

# Label the specific bars with the corresponding data (percentage in this case)
for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() / 2 + bar.get_y(),
            round(bar.get_height()), ha='center',
            color='white', weight='bold', size=10)

# show the plot
plt.show()

# %% [markdown]
# ### Interpretation
#
# Based on the visualized data, we can interpret that individuals who drink alcohol are more likely (although only by a fair bit, strictly according to the bar graph) to have been attacked by heart disease than those who do not.

# %% [markdown]
# ## 6. Are there differences in the prevalence of heart diseases between smokers and non-smokers in the dataset?
#
# ### Variable/s involved
#
# - SmokerStatus
# - HadHeartDisease

# %%
# Get the dataframe with AlcoholDrinkers and HadHeartDisease
smoker_heart_df = heart_df[['SmokerStatus', 'HadHeartDisease']]

# Get the values of SmokerStatus
smoker_status_values = heart_df['SmokerStatus'].unique()

# Create arrays for each of the age values
temp_arr = []

# separate the dataframes for SmokerStatus using query
for smoker in smoker_status_values:
    # convert int to str to be used with .query()
    smoker_str = str(smoker)
    # perform query
    temp_df = smoker_heart_df.query('SmokerStatus == @smoker_str')
    # store the df to the array
    temp_arr.append(temp_df)

# Data
groups = ['Never Smoked', 'Former Smoker', 'Casual Smoker', 'Heavy Smoker']
with_heart_disease_values = []
without_heart_disease_values = []


# get the percentages of the smoker classifications in each age category
for i in range(len(groups)):
    without_heart_disease_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[0])
    with_heart_disease_values.append(
        (temp_arr[i].value_counts(normalize=True) * 100).values[1])

# Brute force
sorted_heart_disease_values = []
sorted_heart_disease_values.append(
    (temp_arr[1].value_counts(normalize=True) * 100).values[1])  # Former Smoker
sorted_heart_disease_values.append(
    (temp_arr[0].value_counts(normalize=True) * 100).values[1])  # Never Smokes
sorted_heart_disease_values.append(
    (temp_arr[3].value_counts(normalize=True) * 100).values[1])  # Heavy Smoker
sorted_heart_disease_values.append(
    (temp_arr[2].value_counts(normalize=True) * 100).values[1])  # Casual Smoker

# %%
# Use Stacked bar chart - https://python-charts.com/part-whole/stacked-bar-chart-matplotlib/
fig, ax = plt.subplots(figsize=(15, 9))

# configure the bars/handles to represent data
ax.bar(groups, sorted_heart_disease_values, edgecolor="black",
       linewidth=2, color="lightseagreen", label="With Heart Disease")

# get the handles and labels using get_legend_handles_labels()
handles, labels = ax.get_legend_handles_labels()
# reverse the order of the labels and handles
ax.legend(handles[::-1], labels[::-1], loc='upper right')

ax.set_ylim(0, 100)

# Set the axis labels
ax.set_ylabel("Percentage of Heart Disease Status")
ax.set_xlabel("Smoker Status")

# Label the specific bars with the corresponding data (percentage in this case)
for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() / 2 + bar.get_y(),
            round(bar.get_height()), ha='center',
            color='white', weight='bold', size=10)

# rotate the x-axis labels for readability
# labels = ax.get_xticklabels()
# for label in labels:
#     label.set_rotation(90)

# show the plot
plt.show()

# %% [markdown]
# ### Interpretation
#
# According to the bar graph above, we can interpret that those who have smoked in the past--no matter the quantity--are more likely to have had heart disease than individuals who have never smoked in their life. We also see that former smokers (according to the dataset) are just as likely to have been attacked by heart disease as heavy smokers, which could either mean that the former smokers quit smoking BECAUSE of their heart disease, or that quitting smoking does not greatly undo the damage it does to organs that some people think it does.

# %% [markdown]
# ## 7. Is there a relationship between a participant’s number of sleep hours and whether or not they have had heart disease?

# %% [markdown]
# ### Variables Involved
#
# - SleepHours
# - HadHeartDisease

# %% [markdown]
# ### Numerical

# %%
# Biserial Correlation Coefficient
from scipy import stats
import pandas as pd

heart_df_copy = heart_df['HadHeartDisease'].map({'Yes': 1, 'No': 0})
correlation_coefficient_biserial = stats.pointbiserialr(
    heart_df_copy, heart_df['SleepHours'])[0]

print(f"Biserial Correlation Coefficient: {correlation_coefficient_biserial}")
# Out:
# Biserial Correlation Coefficient: 0.003630922789500431

# %% [markdown]
# The biserial correlation coefficient is used to assess the relationship between a participant's number of sleep hours and their likelihood of having heart disease due to the presence of a continuous and a binary variable. A biserial correlation coefficient of 0.0036 suggests a very weak, almost negligible, positive relationship between a participant's number of sleep hours and their likelihood of having heart disease.

# %% [markdown]
# ### Visualization

# %%
no_heart_disease = heart_df[heart_df['HadHeartDisease'] == 'No']
yes_heart_disease = heart_df[heart_df['HadHeartDisease'] == 'Yes']

plt.figure(figsize=(15, 9))

plt.hist(no_heart_disease['SleepHours'], alpha=0.5, label='No Heart Disease',
         color="lightseagreen", edgecolor="black", linewidth=2, density=True)
plt.hist(yes_heart_disease['SleepHours'], alpha=0.5, label='Had Heart Disease',
         color="yellowgreen", edgecolor="black", linewidth=2, density=True)

plt.xlabel('Sleep Hours')
plt.ylabel('Percentage')
plt.title('Relationship between Sleep Hours and Heart Disease')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ### Interpretation
#
# According to the overlapping bar chart above, we can see that the individuals who have had heart disease are more likely to have either relatively low or relatively high sleep hours. It cannot be determined as to whether the heart disease is the main cause or effect for these sleep hour statistics, but the strong difference between those who have had heart disease and those who have never had heart disease is quite significant.

# %% [markdown]
# ## 8. Is there a connection between engaging in physical activities and the occurrence of heart disease among the participants?
#
# ### Variable/s involved:
#
# - HadHeartDisease
# - PhysicalActivities

# %% [markdown]
# ### Numerical
#
# The main numerical summary will be the distribution of those with heart diseases among active participants and sedentary participants.
# In order to determine whether or not the test is statistically-significant, we must get the p-value.

# %%
contingency_table = pd.crosstab(
    heart_df['PhysicalActivities'], heart_df['HadHeartDisease'])
chi2, p, _, _ = chi2_contingency(contingency_table)
print("P-value:", p)
# Out:
# P-value: 0.0

# %% [markdown]
# ### Visualization

# %%
heart_df_copy = heart_df.copy()

heart_df_copy['HadHeartDisease'] = heart_df_copy['HadHeartDisease'].map({
                                                                        'Yes': 1, 'No': 0})
physical_activity_heart_disease = heart_df_copy.groupby(
    'PhysicalActivities')['HadHeartDisease'].mean() * 100

ax = physical_activity_heart_disease.plot(kind='bar', stacked=True, color=[
                                          'lightseagreen', 'lightseagreen'], edgecolor="black", linewidth=2, figsize=(15,9))

plt.title('Percentage of People with Heart Disease by Physical Activity', fontsize=16)
plt.xlabel('Whether Partipiants partake in physical activities', fontsize=14)
plt.ylabel('Percentage with Heart Disease', fontsize=14)


for bar in ax.patches:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height / 2 + bar.get_y(),
            f'{height:.1f}%', ha='center', va='center', color='white', size=10)

plt.ylim(0, 100)
plt.show()

# %% [markdown]
# ### Interpretation
#
# According to the bar graph above, we can see that participants who partake in physical activities are less likely to contract heart diseases. This is fairly straight forward to explain as active individuals generally have healthier organs and bodies than individuals with a sedentary lifestyle.

# %% [markdown]
# ## 9. What is the pattern between BMI classification and whether or not they have had heart disease?
#
# ### Variable/s involved:
#
# - BMI
# - HadHeartDisease

# %%
mode_bmi_classification = heart_df['BMI'].mode().iloc[0]
print("Mode BMI:", mode_bmi_classification)
# Out:
# Mode BMI: Overweight

# %%
heart_df['BMI'] = heart_df['BMI'].astype('category')

count_table = pd.crosstab(heart_df['BMI'], heart_df['HadHeartDisease'])

count_table_percentage = count_table.div(
    count_table.sum(1).astype(float), axis=0)

normalized_df = pd.DataFrame({
    'BMI': count_table_percentage.index,
    # Multiply by 100 to get percentage
    'Heart Disease': count_table_percentage['Yes'] * 100,
    # Multiply by 100 to get percentage
    'No Heart Disease': count_table_percentage['No'] * 100,
})

plt.figure(figsize=(15, 9))
ax = sns.barplot(x='BMI', y='Heart Disease', data=normalized_df,
                 color="tomato", label='Heart Disease')
ax = sns.barplot(x='BMI', y='No Heart Disease', data=normalized_df, color="white",
                 label='No Heart Disease', bottom=normalized_df['Heart Disease'])

plt.xlabel('BMI')
plt.ylabel('Percentage')
plt.title('Pattern Between BMI and Heart Disease')


legend_elements = [Patch(color='tomato', label='Heart Disease')]
ax.legend(handles=legend_elements)

for bar in ax.patches:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height / 2 + bar.get_y(),
            f'{height:.1f}%', ha='center', va='center', color='white', size=10)


plt.show()

# %%
heart_df
# Out:
#        GeneralHealth  Age HadHeartDisease         BMI AlcoholDrinkers  \
# 0          Very good   65              No  Overweight              No
# 1          Very good   70              No       Obese              No
# 2          Very good   75              No       Obese             Yes
# 3               Fair   80              No       Obese              No
# 4               Good   80              No       Obese              No
# ...              ...  ...             ...         ...             ...
# 246017     Very good   60              No       Obese             Yes
# 246018          Fair   25              No      Normal              No
# 246019          Good   65              No  Overweight             Yes
# 246020     Excellent   50              No  Overweight              No
# 246021     Very good   70             Yes       Obese              No
#
#          SmokerStatus  SleepHours PhysicalActivities
# 0       Former smoker           9                Yes
# ...

# %% [markdown]
# ### Interpretation
#
# According to the bar chart above, we can see that although there does not seem to be much difference among the different BMI categories, we can see that BMI categories from "Obese" to "Super Obese" reach a percentage of 6% or above, a figure that all other BMI categories do not reach. Therefore it can be interpreted that--albeit not that huge--there is a general increase in likelihood of getting a heart disease if you have a high BMI rating.

# %% [markdown]
# ## 10. Is there a pattern behind a participant’s self-reported general health status and whether or not they have had heart disease
#
# ### Variable/s involved:
#
# - GeneralHealth
# - HadHeartDisease?

# %% [markdown]
# ### Numerical
#
# The main numerical summary will be the distribution of those with heart diseases among participants' self-reported general health status.
# In order to determine whether or not the test is statistically-significant, we must get the p-value.

# %%
contingency_table = pd.crosstab(
    heart_df['GeneralHealth'], heart_df['HadHeartDisease'])
chi2, p, _, _ = chi2_contingency(contingency_table)
print("Chi-Square Value:", chi2)
print("P-value:", p)
# Out:
# Chi-Square Value: 9893.915405890815
# P-value: 0.0

# %% [markdown]
# ### Visualization

# %%
heart_df['GeneralHealth'] = pd.Categorical(heart_df['GeneralHealth'], categories=[
                                           'Poor', 'Fair', 'Good', 'Very good', 'Excellent'], ordered=True)

count_table = pd.crosstab(
    heart_df['GeneralHealth'], heart_df['HadHeartDisease'])

count_table_percentage = count_table.div(
    count_table.sum(1).astype(float), axis=0)

normalized_df = pd.DataFrame({
    'GeneralHealth': count_table_percentage.index,
    # Multiply by 100 to get percentage
    'Heart Disease': count_table_percentage['Yes'] * 100,
    # Multiply by 100 to get percentage
    'No Heart Disease': count_table_percentage['No'] * 100,
})

plt.figure(figsize=(15, 6))
ax = sns.barplot(x='GeneralHealth', y='Heart Disease',
                 data=normalized_df, color="tomato", label='Heart Disease')
ax = sns.barplot(x='GeneralHealth', y='No Heart Disease', data=normalized_df,
                 color="white", label='No Heart Disease', bottom=normalized_df['Heart Disease'])

plt.xlabel('Self-Perceived General Health Status')
plt.ylabel('Percentage')
plt.title('Pattern Between BMI and Heart Disease')


legend_elements = [Patch(color='tomato', label='Heart Disease')]
ax.legend(handles=legend_elements)

for bar in ax.patches:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height / 2 + bar.get_y(),
            f'{height:.1f}%', ha='center', va='center', color='white', size=10)


plt.show()

# %% [markdown]
# ### Interpretation
#
# According to the bar graph above, we can see that the individuals are quite truthful in their self-perception of their health status, as we see that those who have a self-perceived health status of "Poor", "Fair", and "Good" are more likely to have had heart disease. Therefore we can say that there is some underlying truth to an individual's "gut feeling" about their overall health.

# %% [markdown]
# # VI. **Research Question**
#
# ---
#
# Given the exploratory data analysis performed with the chosen variables, the group has come up with a research question that can be answered using the chosen dataset:
#
# ### RQ: What are the general lifestyle-related aspects that can be indicative of the likelihood of developing heart disease?
#
# As per the graphs and charts generated above, we could see that the impact of certain lifestyle factors influence one's probability of contracting a heart disease. With some factors, such as smoking, playing a much bigger role than that of one's self perception about their general health status.
#
# Finding the answer to the research question above is important as now more than ever, people are more likely to die from cardiovascular diseases than any other sickness. This comes from a joint study performed by the IHME Global Burden of Disease and the Global Terrorism Database, where heart disease has been identified as the largest cause of death globally, accounting for 33% of all deaths in 2019 alone.
#
# Therefore, it is our goal for the next part of this study to figure out which lifestyle factors exert the most significant influence on the prevalence of heart disease within individuals.

# %% [markdown]
# # VII. Data Modelling
# ---

# %%
heart_df
# Out:
#        GeneralHealth  Age HadHeartDisease         BMI AlcoholDrinkers  \
# 0          Very good   65              No  Overweight              No
# 1          Very good   70              No       Obese              No
# 2          Very good   75              No       Obese             Yes
# 3               Fair   80              No       Obese              No
# 4               Good   80              No       Obese              No
# ...              ...  ...             ...         ...             ...
# 246017     Very good   60              No       Obese             Yes
# 246018          Fair   25              No      Normal              No
# 246019          Good   65              No  Overweight             Yes
# 246020     Excellent   50              No  Overweight              No
# 246021     Very good   70             Yes       Obese              No
#
#          SmokerStatus  SleepHours PhysicalActivities
# 0       Former smoker           9                Yes
# ...

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246022 entries, 0 to 246021
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   GeneralHealth       246022 non-null  category
#  1   Age                 246022 non-null  int32
#  2   HadHeartDisease     246022 non-null  object
#  3   BMI                 246022 non-null  category
#  4   AlcoholDrinkers     246022 non-null  object
#  5   SmokerStatus        246022 non-null  object
#  6   SleepHours          246022 non-null  int32
#  7   PhysicalActivities  246022 non-null  object
# dtypes: category(2), int32(2), object(4)
# memory usage: 9.9+ MB

# %%
# Get respondents with heart disease
heart_df_with = heart_df[heart_df['HadHeartDisease'] == 'Yes']

# Get respondents without heart disease
heart_df_without = heart_df[heart_df['HadHeartDisease'] == 'No']

# Trim respondents without heart disease to match number of those with heart disease
heart_df_without = heart_df_without.sample(n=heart_df_with.shape[0])

# Concatenate the two dataframes
heart_df_filtered = pd.concat([heart_df_without, heart_df_with])

""" INSERT BINNING CODE HERE """

heart_df_filtered
# Out:
#        GeneralHealth  Age HadHeartDisease             BMI AlcoholDrinkers  \
# 29946           Good   70              No           Obese              No
# 36467      Excellent   60              No      Overweight             Yes
# 15665      Very good   40              No  Severely Obese              No
# 108831     Excellent   18              No          Normal              No
# 222507     Very good   75              No      Overweight             Yes
# ...              ...  ...             ...             ...             ...
# 245922          Fair   80             Yes      Overweight             Yes
# 245943          Fair   35             Yes           Obese              No
# 246012          Fair   65             Yes           Obese             Yes
# 246016          Good   55             Yes  Severely Obese             Yes
# 246021     Very good   70             Yes           Obese              No
#
#                                  SmokerStatus  SleepHours PhysicalActivities
# ...

# %%
# One Hot Encoding
heart_df_encoded_filtered = pd.get_dummies(heart_df_filtered, columns=['SmokerStatus', 'BMI', 'GeneralHealth', 'Age', 'SleepHours'])
heart_df_encoded_filtered['HadHeartDisease'] = heart_df_encoded_filtered['HadHeartDisease'].map({'Yes': 1, 'No': 0})
heart_df_encoded_filtered['AlcoholDrinkers'] = heart_df_encoded_filtered['AlcoholDrinkers'].map({'Yes': 1, 'No': 0})
heart_df_encoded_filtered['PhysicalActivities'] = heart_df_encoded_filtered['PhysicalActivities'].map({'Yes': 1, 'No': 0})
heart_df_encoded_filtered = heart_df_encoded_filtered.astype(int)

heart_df_encoded_filtered
# Out:
#         HadHeartDisease  AlcoholDrinkers  PhysicalActivities  \
# 29946                 0                0                   1
# 36467                 0                1                   1
# 15665                 0                0                   1
# 108831                0                0                   1
# 222507                0                1                   1
# ...                 ...              ...                 ...
# 245922                1                1                   0
# 245943                1                0                   1
# 246012                1                1                   0
# 246016                1                1                   0
# 246021                1                0                   0
#
#         SmokerStatus_Current smoker - now smokes every day  \
# 29946                                                   0
# 36467                                                   0
# ...

# %%
""" FUNCTION FOR GETTING THE ASSOCIATION RULES """
# Use Apriori algorithm to find frequent itemsets
def get_association_rules(dataframe, s_threshold, c_threshold):
    frequent_itemsets = apriori(dataframe, min_support=s_threshold, use_colnames=True)

    # Generate association rules
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=c_threshold)

    return rules

# %%
rules = get_association_rules(heart_df_encoded_filtered, 0.25, 0.7)
print(rules)
# Out:
#                    antecedents           consequents  antecedent support  \
# 0            (AlcoholDrinkers)  (PhysicalActivities)            0.476405
# 1  (SmokerStatus_Never smoked)  (PhysicalActivities)            0.512319
# 2             (BMI_Overweight)  (PhysicalActivities)            0.362784
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.709267  0.376517    0.790329  1.114290  0.038618    1.386615
# 1            0.709267  0.386937    0.755267  1.064855  0.023567    1.187959
# 2            0.709267  0.272162    0.750205  1.057719  0.014852    1.163888
#
#    zhangs_metric
# 0       0.195891
# 1       0.124888
# 2       0.085637

# %%
# check the columns again
for c in heart_df_encoded_filtered.columns:
    print ("---- %s ---" % c)
    print (heart_df_encoded_filtered[c].value_counts())
# Out:
# ---- HadHeartDisease ---
# HadHeartDisease
# 0    13435
# 1    13435
# Name: count, dtype: int64
# ---- AlcoholDrinkers ---
# AlcoholDrinkers
# 0    14069
# 1    12801
# Name: count, dtype: int64
# ---- PhysicalActivities ---
# PhysicalActivities
# 1    19058
# 0     7812
# Name: count, dtype: int64
# ---- SmokerStatus_Current smoker - now smokes every day ---
# SmokerStatus_Current smoker - now smokes every day
# 0    23924
# 1     2946
# Name: count, dtype: int64
# ---- SmokerStatus_Current smoker - now smokes some days ---
# SmokerStatus_Current smoker - now smokes some days
# 0    25884
# 1      986
# Name: count, dtype: int64
# ---- SmokerStatus_Former smoker ---
# SmokerStatus_Former smoker
# 0    17698
# 1     9172
# Name: count, dtype: int64
# ---- SmokerStatus_Never smoked ---
# SmokerStatus_Never smoked
# 1    13766
# 0    13104
# Name: count, dtype: int64
# ---- BMI_Underweight ---
# BMI_Underweight
# 0    26498
# 1      372
# Name: count, dtype: int64
# ...

# %%
for c in heart_df_encoded_filtered.columns:
    print ("---- %s ---" % c)
# Out:
# ---- HadHeartDisease ---
# ---- AlcoholDrinkers ---
# ---- PhysicalActivities ---
# ---- SmokerStatus_Current smoker - now smokes every day ---
# ---- SmokerStatus_Current smoker - now smokes some days ---
# ---- SmokerStatus_Former smoker ---
# ---- SmokerStatus_Never smoked ---
# ---- BMI_Underweight ---
# ---- BMI_Normal ---
# ---- BMI_Overweight ---
# ---- BMI_Obese ---
# ---- BMI_Severely Obese ---
# ---- BMI_Morbidly Obese ---
# ---- BMI_Super Obese ---
# ---- GeneralHealth_Poor ---
# ---- GeneralHealth_Fair ---
# ---- GeneralHealth_Good ---
# ---- GeneralHealth_Very good ---
# ---- GeneralHealth_Excellent ---
# ---- Age_18 ---
# ---- Age_25 ---
# ---- Age_30 ---
# ---- Age_35 ---
# ---- Age_40 ---
# ---- Age_45 ---
# ---- Age_50 ---
# ---- Age_55 ---
# ---- Age_60 ---
# ---- Age_65 ---
# ---- Age_70 ---
# ---- Age_75 ---
# ---- Age_80 ---
# ---- SleepHours_1 ---
# ---- SleepHours_2 ---
# ---- SleepHours_3 ---
# ---- SleepHours_4 ---
# ---- SleepHours_5 ---
# ...

# %% [markdown]
# # Testing Area
# ---

# %% [markdown]
# Pre-processing

# %% [markdown]
# # bin the

# %%
heart_df_copy = heart_df.copy()
heart_df_copy
# Out:
#        GeneralHealth  Age HadHeartDisease         BMI AlcoholDrinkers  \
# 0          Very good   65              No  Overweight              No
# 1          Very good   70              No       Obese              No
# 2          Very good   75              No       Obese             Yes
# 3               Fair   80              No       Obese              No
# 4               Good   80              No       Obese              No
# ...              ...  ...             ...         ...             ...
# 246017     Very good   60              No       Obese             Yes
# 246018          Fair   25              No      Normal              No
# 246019          Good   65              No  Overweight             Yes
# 246020     Excellent   50              No  Overweight              No
# 246021     Very good   70             Yes       Obese              No
#
#          SmokerStatus  SleepHours PhysicalActivities
# 0       Former smoker           9                Yes
# ...

# %%
heart_df_copy['Age'].unique()
# Out:
# array([65, 70, 75, 80, 50, 40, 60, 55, 45, 35, 25, 30, 18])

# %% [markdown]
# bin the age category

# %%
# Define the bins and labels
bins = [0, 44, float('inf')]
labels = ['0-44', '45+']

# Use the cut function to categorize the 'Age' column
heart_df_copy['Age'] = pd.cut(heart_df_copy['Age'], bins=bins, labels=labels, right=False)

heart_df_copy.rename(columns={'Age': 'OldAge'}, inplace=True)

# Display the resulting dataframe
print(heart_df_copy)
# Out:
#        GeneralHealth OldAge HadHeartDisease         BMI AlcoholDrinkers  \
# 0          Very good    45+              No  Overweight              No
# 1          Very good    45+              No       Obese              No
# 2          Very good    45+              No       Obese             Yes
# 3               Fair    45+              No       Obese              No
# 4               Good    45+              No       Obese              No
# ...              ...    ...             ...         ...             ...
# 246017     Very good    45+              No       Obese             Yes
# 246018          Fair   0-44              No      Normal              No
# 246019          Good    45+              No  Overweight             Yes
# 246020     Excellent    45+              No  Overweight              No
# 246021     Very good    45+             Yes       Obese              No
#
#          SmokerStatus  SleepHours PhysicalActivities
# ...

# %%
heart_df_copy['OldAge'].unique()
# Out:
# ['45+', '0-44']
# Categories (2, object): ['0-44' < '45+']

# %% [markdown]
# bin the smoker category

# %%
heart_df_copy['SmokerStatus'].unique()
# Out:
# array(['Former smoker', 'Never smoked',
#        'Current smoker - now smokes every day',
#        'Current smoker - now smokes some days'], dtype=object)

# %%
smoker_mapping = {
    'Former smoker': 'Yes',
    'Never smoked': 'No',
    'Current smoker - now smokes every day': 'Yes',
    'Current smoker - now smokes some days': 'Yes'
}

# Use the replace function to map values
heart_df_copy['SmokerStatus'] = heart_df_copy['SmokerStatus'].replace(smoker_mapping)

# rename the column
heart_df_copy.rename(columns={'SmokerStatus': 'CurrentSmoker'}, inplace=True)

# Display the resulting dataframe
print(heart_df_copy)
# Out:
#        GeneralHealth OldAge HadHeartDisease         BMI AlcoholDrinkers  \
# 0          Very good    45+              No  Overweight              No
# 1          Very good    45+              No       Obese              No
# 2          Very good    45+              No       Obese             Yes
# 3               Fair    45+              No       Obese              No
# 4               Good    45+              No       Obese              No
# ...              ...    ...             ...         ...             ...
# 246017     Very good    45+              No       Obese             Yes
# 246018          Fair   0-44              No      Normal              No
# 246019          Good    45+              No  Overweight             Yes
# 246020     Excellent    45+              No  Overweight              No
# 246021     Very good    45+             Yes       Obese              No
#
#        CurrentSmoker  SleepHours PhysicalActivities
# ...

# %%
heart_df_copy['CurrentSmoker'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# bin the sleep hours

# %%
heart_df_copy['SleepHours'].unique()
# Out:
# array([ 9,  6,  8,  5,  7, 10,  4, 12,  3, 18, 11,  2,  1, 16, 14, 15, 13,
#        20, 24, 23, 19, 17, 22])

# %%
# Define a function to map sleep hours to 'Yes' or 'No'
def categorize_sleep_hours(hours):
    return 'Yes' if 7 <= hours <= 10 else 'No'

# Apply the function to create a new column 'Sleep_Category'
heart_df_copy['SleepHours'] = heart_df_copy['SleepHours'].apply(lambda x: categorize_sleep_hours(x))

# rename the column 'SleepHours'
heart_df_copy.rename(columns={'SleepHours': 'HealthySleep'}, inplace=True)

# Display the resulting dataframe
print(heart_df_copy)
# Out:
#        GeneralHealth OldAge HadHeartDisease         BMI AlcoholDrinkers  \
# 0          Very good    45+              No  Overweight              No
# 1          Very good    45+              No       Obese              No
# 2          Very good    45+              No       Obese             Yes
# 3               Fair    45+              No       Obese              No
# 4               Good    45+              No       Obese              No
# ...              ...    ...             ...         ...             ...
# 246017     Very good    45+              No       Obese             Yes
# 246018          Fair   0-44              No      Normal              No
# 246019          Good    45+              No  Overweight             Yes
# 246020     Excellent    45+              No  Overweight              No
# 246021     Very good    45+             Yes       Obese              No
#
#        CurrentSmoker HealthySleep PhysicalActivities
# ...

# %% [markdown]
# bin general health

# %%
# poor, fair, good 
# very good, excellent
heart_df_copy['GeneralHealth'].unique()
# Out:
# ['Very good', 'Fair', 'Good', 'Excellent', 'Poor']
# Categories (5, object): ['Poor' < 'Fair' < 'Good' < 'Very good' < 'Excellent']

# %%
general_health_mapping = {
    'Poor': 'Needs Improvement',
    'Fair': 'Needs Improvement',
    'Good': 'Needs Improvement',
    'Very good': 'Thriving',
    'Excellent': 'Thriving'
}

# Use the replace function to map values
heart_df_copy['GeneralHealth'] = heart_df_copy['GeneralHealth'].replace(general_health_mapping)

# %%
heart_df_copy['GeneralHealth'].unique()
# Out:
# ['Thriving', 'Needs Improvement']
# Categories (2, object): ['Needs Improvement' < 'Thriving']

# %% [markdown]
# bin the bmi

# %%
heart_df_copy['BMI'].unique()
# Out:
# ['Overweight', 'Obese', 'Severely Obese', 'Normal', 'Morbidly Obese', 'Underweight', 'Super Obese']
# Categories (7, object): ['Underweight' < 'Normal' < 'Overweight' < 'Obese' < 'Severely Obese' < 'Morbidly Obese' < 'Super Obese']

# %%
# underweight, normal - healthy weight
# overweight - increased weight
bmi_mapping = { 
    'Underweight': 'Healthy Weight',
    'Normal': 'Healthy Weight',
    'Overweight': 'Increased Weight',
    'Obese': 'Increased Weight',
    'Severely Obese': 'Increased Weight',
    'Morbidly Obese': 'Increased Weight',
    'Super Obese': 'Increased Weight'
} 

# Use the replace function to map values
heart_df_copy['BMI'] = heart_df_copy['BMI'].replace(bmi_mapping)

# %%
heart_df_copy['BMI'].unique()
# Out:
# ['Increased Weight', 'Healthy Weight']
# Categories (2, object): ['Healthy Weight' < 'Increased Weight']

# %%
heart_df_copy
# Out:
#             GeneralHealth OldAge HadHeartDisease               BMI  \
# 0                Thriving    45+              No  Increased Weight
# 1                Thriving    45+              No  Increased Weight
# 2                Thriving    45+              No  Increased Weight
# 3       Needs Improvement    45+              No  Increased Weight
# 4       Needs Improvement    45+              No  Increased Weight
# ...                   ...    ...             ...               ...
# 246017           Thriving    45+              No  Increased Weight
# 246018  Needs Improvement   0-44              No    Healthy Weight
# 246019  Needs Improvement    45+              No  Increased Weight
# 246020           Thriving    45+              No  Increased Weight
# 246021           Thriving    45+             Yes  Increased Weight
#
#        AlcoholDrinkers CurrentSmoker HealthySleep PhysicalActivities
# 0                   No           Yes          Yes                Yes
# ...

# %%
# Get respondents with heart disease
heart_df_with = heart_df_copy[heart_df_copy['HadHeartDisease'] == 'Yes']

# Get respondents without heart disease
heart_df_without = heart_df_copy[heart_df_copy['HadHeartDisease'] == 'No']

# Trim respondents without heart disease to match number of those with heart disease
heart_df_without = heart_df_without.sample(n=heart_df_with.shape[0])

# Concatenate the two dataframes
heart_df_filtered = pd.concat([heart_df_without, heart_df_with])

# %%
heart_df_filtered
# Out:
#             GeneralHealth OldAge HadHeartDisease               BMI  \
# 245396           Thriving   0-44              No    Healthy Weight
# 222431           Thriving    45+              No  Increased Weight
# 39184            Thriving   0-44              No    Healthy Weight
# 130379           Thriving   0-44              No  Increased Weight
# 122071           Thriving    45+              No    Healthy Weight
# ...                   ...    ...             ...               ...
# 245922  Needs Improvement    45+             Yes  Increased Weight
# 245943  Needs Improvement   0-44             Yes  Increased Weight
# 246012  Needs Improvement    45+             Yes  Increased Weight
# 246016  Needs Improvement    45+             Yes  Increased Weight
# 246021           Thriving    45+             Yes  Increased Weight
#
#        AlcoholDrinkers CurrentSmoker HealthySleep PhysicalActivities
# 245396             Yes            No           No                 No
# ...

# %%
# change the values of the dataframe to boolean


# One Hot Encoding
heart_df_encoded_filtered = pd.get_dummies(heart_df_filtered, columns=['GeneralHealth', 'OldAge', 'BMI', 'HadHeartDisease', 'CurrentSmoker', 'PhysicalActivities', 'AlcoholDrinkers', 'HealthySleep'])
# heart_df_encoded_filtered = heart_df_copy.copy()

""" heart_df_encoded_filtered['HadHeartDisease'] = heart_df_encoded_filtered['HadHeartDisease'].map({'Yes': 1, 'No': 0})
heart_df_encoded_filtered['AlcoholDrinkers'] = heart_df_encoded_filtered['AlcoholDrinkers'].map({'Yes': 1, 'No': 0})
heart_df_encoded_filtered['PhysicalActivities'] = heart_df_encoded_filtered['PhysicalActivities'].map({'Yes': 1, 'No': 0}) """

# encode bmi
""" heart_df_encoded_filtered['HadHeartDisease'] = heart_df_encoded_filtered['HadHeartDisease'].map({'Yes': 1, 'No': 0})
heart_df_encoded_filtered['AlcoholDrinkers'] = heart_df_encoded_filtered['AlcoholDrinkers'].map({'Yes': 1, 'No': 0})
heart_df_encoded_filtered['PhysicalActivities'] = heart_df_encoded_filtered['PhysicalActivities'].map({'Yes': 1, 'No': 0}) """

""" heart_df_encoded_filtered['HadHeartDisease'] = heart_df_encoded_filtered['HadHeartDisease'].map({'Yes': 1, 'No': 0})
heart_df_encoded_filtered['Age'] = heart_df_encoded_filtered['Age'].map({'45+': 1, '0-44': 0})
heart_df_encoded_filtered['GeneralHealth'] = heart_df_encoded_filtered['GeneralHealth'].map({'Thriving': 1, 'Needs Improvement': 0})
heart_df_encoded_filtered['BMI'] = heart_df_encoded_filtered['BMI'].map({'Healthy Weight': 1, 'Increased Weight': 0})
heart_df_encoded_filtered['CurrentSmoker'] = heart_df_encoded_filtered['CurrentSmoker'].map({'Yes': 1, 'No': 0}) """

# heart_df_encoded_filtered = heart_df_encoded_filtered.astype(int)
# to 0 and apply it to each column using .apply()
heart_df_encoded_filtered = heart_df_encoded_filtered.apply(lambda x: x.apply(lambda y: 1 if y else 0))
heart_df_encoded_filtered = heart_df_encoded_filtered.astype(int)

heart_df_encoded_filtered
# Out:
#         GeneralHealth_Needs Improvement  GeneralHealth_Thriving  OldAge_0-44  \
# 245396                                0                       1            1
# 222431                                0                       1            0
# 39184                                 0                       1            1
# 130379                                0                       1            1
# 122071                                0                       1            0
# ...                                 ...                     ...          ...
# 245922                                1                       0            0
# 245943                                1                       0            1
# 246012                                1                       0            0
# 246016                                1                       0            0
# 246021                                0                       1            0
#
# ...

# %% [markdown]
# Association rule mining

# %%
rules = get_association_rules(heart_df_encoded_filtered, 0.29, 0.6) 

# To display more rows
pd.set_option('display.max_rows', None)

# To display more columns
pd.set_option('display.max_columns', None)

print(rules)
# Out:
#                                            antecedents  \
# 0                    (GeneralHealth_Needs Improvement)
# 1                                         (OldAge_45+)
# 2                    (GeneralHealth_Needs Improvement)
# 3                               (BMI_Increased Weight)
# 4                                (HadHeartDisease_Yes)
# 5                    (GeneralHealth_Needs Improvement)
# 6                                  (CurrentSmoker_Yes)
# 7                    (GeneralHealth_Needs Improvement)
# 8                                 (AlcoholDrinkers_No)
# 9                             (GeneralHealth_Thriving)
# 10                              (BMI_Increased Weight)
# 11                                        (OldAge_45+)
# 12                                (HadHeartDisease_No)
# 13                               (HadHeartDisease_Yes)
# 14                                  (CurrentSmoker_No)
# 15                                 (CurrentSmoker_Yes)
# ...
